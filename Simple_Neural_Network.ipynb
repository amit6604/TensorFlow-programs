# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/amit6604/TensofFlow-programs/blob/master/Simple_Neural_Network.ipynb)

# %%
import tensorflow as tf

# %% [markdown]
# # Introduction
#
# In this tutorial, we'll be introducing neural networks and looking at how to classify digits with these machine learning models. As with all supervised learning methods, we have some (input, output) pairs which we denote as (xi,yi) and we have n of these, so i∈[1...n]. We want to learn a function f:x→y that maps inputs to outputs.
#
# Today, we're going to look at classifying digits. The inputs will be a 28 x 28 black and white image, and the output will be a 10 dimensional vector that represents the probabilities for each of the 10 digits. From these probabilities, you can then choose the probability with the highest value to produce a single value that best representing the number in the image.
#
#
# The dataset we're going to be using is called MNIST. MNIST is a dataset of over 60,000 handwritten digits and the corresponding labels of the digits the image represents. It is easily the most used dataset in machine learning. We'll start this tutorial by using the Tensorflow API to load in the dataset.

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-2-8bf8ae5a5303>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
batch_size = 100
input_size = 784

# %%
tf.reset_default_graph() # Spawn new graph every time
X = tf.placeholder(tf.float32, shape = [None, input_size])
y = tf.placeholder(tf.float32, shape = [None, 10])

# %% [markdown]
# Next, we will define the weight matrices and bias terms. The key when defining these variable is to keep track of the shapes and to make sure that the output matrix of the previous layer is able to multiply with the weight matrix of the next layer.

# %%
W1 = tf.Variable(tf.truncated_normal([input_size, 50], stddev=0.1))
B1 = tf.Variable(tf.constant(0.1), [50]) # Number of Hidden units is 50 here.
W2 = tf.Variable(tf.truncated_normal([50, 10])) # No of output class is 10 here 0-9
B2 = tf.Variable(tf.constant(0.1), [10])

# %% [markdown]
# Now, we will define the matrix multiplication operations and follow each matrix multiply with a non linear layer

# %%
hiddenLayerOutput = tf.matmul(X, W1) + B1
hiddenLayerOutput = tf.nn.relu(hiddenLayerOutput)
finalOutput = tf.matmul(hiddenLayerOutput, W2) + B2
finalOutput = tf.nn.relu(finalOutput)

# %% [markdown]
# # Loss Function
#
# Now that we know how the input gets fed through the network, we can analyze the output. The output is a vector that represents the probabilities for the classes. We then want to compare this prediction with the label, and then minimize the loss using a Tensorflow optimizer.

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels = y, logits = finalOutput))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.1).minimize(loss)

# %%
prediction = tf.equal(tf.argmax(finalOutput, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(prediction, "float"))

# %% [markdown]
# # Training
#
# Here's the part where we start training our model. We'll load in our training set by calling Tensorflow's mnist.train.next_batch() function. The sess.run function has two arguments. The first is called the "fetches" argument. It defines the value for you're interested in computing/running. For example, in our case, we want to both run the optimizer object so that the cross entropy loss gets minimized and evaluate the current loss value (in case we want to print that value). Therefore, we'll use [opt, loss] for our first argument. The second argument is where we input our feed_dict. This data structure is where we provide values to all of our placeholders. We repeat this for a set number of iterations.

# %%
# create session

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for i in range(1000): # No of iteration is 1000
  batch = mnist.train.next_batch(100)
  batchInput = batch[0]
  batchLabels = batch[1]
  _, trainingLoss = sess.run([optimizer, loss], feed_dict={X: batchInput, y: batchLabels})
  if i%10 ==0:
    trainAccuracy = accuracy.eval(session=sess, feed_dict={X: batchInput, y: batchLabels})
    print ("step %d training accuracy %g"%(i,trainAccuracy))
# Out:
# step 0 training accuracy 0.25
# step 10 training accuracy 0.46
# step 20 training accuracy 0.55
# step 30 training accuracy 0.53
# step 40 training accuracy 0.75
# step 50 training accuracy 0.71
# step 60 training accuracy 0.76
# step 70 training accuracy 0.89
# step 80 training accuracy 0.89
# step 90 training accuracy 0.89
# step 100 training accuracy 0.89
# step 110 training accuracy 0.88
# step 120 training accuracy 0.96
# step 130 training accuracy 0.94
# step 140 training accuracy 0.96
# step 150 training accuracy 0.96
# step 160 training accuracy 0.98
# step 170 training accuracy 0.97
# step 180 training accuracy 0.94
# step 190 training accuracy 0.97
# step 200 training accuracy 0.94
# step 210 training accuracy 0.95
# step 220 training accuracy 0.99
# step 230 training accuracy 0.94
# step 240 training accuracy 0.85
# step 250 training accuracy 0.95
# step 260 training accuracy 0.94
# step 270 training accuracy 0.96
# step 280 training accuracy 0.96
# step 290 training accuracy 0.98
# step 300 training accuracy 0.91
# step 310 training accuracy 0.94
# step 320 training accuracy 0.95
# step 330 training accuracy 0.96
# step 340 training accuracy 0.95
# step 350 training accuracy 0.95
# step 360 training accuracy 0.92
# step 370 training accuracy 0.93
# step 380 training accuracy 0.99
# step 390 training accuracy 0.95
# step 400 training accuracy 0.97
# step 410 training accuracy 0.96
# step 420 training accuracy 0.92
# step 430 training accuracy 0.95
# step 440 training accuracy 0.99
# step 450 training accuracy 0.97
# step 460 training accuracy 0.98
# step 470 training accuracy 0.97
# step 480 training accuracy 0.97
# step 490 training accuracy 0.94
# step 500 training accuracy 0.96
# step 510 training accuracy 0.96
# step 520 training accuracy 0.94
# step 530 training accuracy 0.98
# step 540 training accuracy 0.94
# step 550 training accuracy 0.98
# step 560 training accuracy 0.95
# step 570 training accuracy 0.95
# step 580 training accuracy 0.96
# step 590 training accuracy 0.93
# step 600 training accuracy 0.96
# step 610 training accuracy 0.97
# step 620 training accuracy 0.98
# step 630 training accuracy 0.96
# step 640 training accuracy 0.97
# step 650 training accuracy 0.93
# step 660 training accuracy 0.94
# step 670 training accuracy 0.99
# step 680 training accuracy 0.97
# step 690 training accuracy 0.97
# step 700 training accuracy 0.95
# step 710 training accuracy 0.98
# step 720 training accuracy 0.98
# step 730 training accuracy 0.99
# step 740 training accuracy 0.94
# step 750 training accuracy 0.99
# step 760 training accuracy 0.96
# step 770 training accuracy 0.97
# step 780 training accuracy 0.99
# step 790 training accuracy 0.99
# step 800 training accuracy 0.95
# step 810 training accuracy 0.97
# step 820 training accuracy 0.97
# step 830 training accuracy 0.97
# step 840 training accuracy 0.99
# step 850 training accuracy 0.95
# step 860 training accuracy 0.98
# step 870 training accuracy 0.96
# step 880 training accuracy 1
# step 890 training accuracy 0.96
# step 900 training accuracy 0.97
# step 910 training accuracy 0.96
# step 920 training accuracy 0.97
# step 930 training accuracy 0.97
# step 940 training accuracy 0.96
# step 950 training accuracy 1
# step 960 training accuracy 0.94
# step 970 training accuracy 0.96
# step 980 training accuracy 0.96
# step 990 training accuracy 0.97

# %% [markdown]
# # Testing
#
# Now, we will test the network on data that it has never seen before.

# %%
tf.reset_default_graph()

X = tf.placeholder(tf.float32, shape = [None, input_size])
y = tf.placeholder(tf.float32, shape = [None, 10])

W1 = tf.Variable(tf.random_normal([input_size, 50], stddev=0.1))
B1 = tf.Variable(tf.constant(0.1), [50])
W2 = tf.Variable(tf.random_normal([50, 100], stddev=0.1))
B2 = tf.Variable(tf.constant(0.1), [100])
W3 = tf.Variable(tf.random_normal([100, 10], stddev=0.1))
B3 = tf.Variable(tf.constant(0.1), [10])

hiddenLayer1Output = tf.matmul(X, W1) + B1
hiddenLayer1Output = tf.nn.relu(hiddenLayer1Output)
hiddenLayer2Output = tf.matmul(hiddenLayer1Output, W2) + B2
hiddenLayer2Output = tf.nn.relu(hiddenLayer2Output)
finalOutput = tf.matmul(hiddenLayer2Output, W3) + B3

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels = y, logits = finalOutput))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.1).minimize(loss)

prediction = tf.equal(tf.argmax(finalOutput,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(prediction, "float"))

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for i in range(10000):
  batch = mnist.train.next_batch(100)
  batchInput = batch[0]
  batchLabels = batch[1]
  _, trainingLoss = sess.run([optimizer, loss], feed_dict={X: batchInput, y:batchLabels})
  if i%10 ==0:
    train_accuracy = accuracy.eval(session=sess, feed_dict={X:batchInput, y:batchLabels})
    print("Step %d , training accuracy %g"%(i, train_accuracy))
    
   

testInput = mnist.test.images
testLabels = mnist.test.labels
acc = accuracy.eval(session=sess, feed_dict ={X:testInput, y:testLabels})
print("testing accuracy: {}".format(acc))
# Out:
# Step 0 , training accuracy 0.15
# Step 10 , training accuracy 0.54
# Step 20 , training accuracy 0.63
# Step 30 , training accuracy 0.76
# Step 40 , training accuracy 0.74
# Step 50 , training accuracy 0.75
# Step 60 , training accuracy 0.86
# Step 70 , training accuracy 0.78
# Step 80 , training accuracy 0.88
# Step 90 , training accuracy 0.88
# Step 100 , training accuracy 0.83
# Step 110 , training accuracy 0.83
# Step 120 , training accuracy 0.86
# Step 130 , training accuracy 0.93
# Step 140 , training accuracy 0.84
# Step 150 , training accuracy 0.95
# Step 160 , training accuracy 0.87
# Step 170 , training accuracy 0.85
# Step 180 , training accuracy 0.91
# Step 190 , training accuracy 0.93
# Step 200 , training accuracy 0.95
# Step 210 , training accuracy 0.92
# Step 220 , training accuracy 0.94
# Step 230 , training accuracy 0.98
# Step 240 , training accuracy 0.91
# Step 250 , training accuracy 0.94
# Step 260 , training accuracy 0.95
# Step 270 , training accuracy 0.91
# Step 280 , training accuracy 0.93
# Step 290 , training accuracy 0.9
# Step 300 , training accuracy 0.93
# Step 310 , training accuracy 0.89
# Step 320 , training accuracy 0.93
# Step 330 , training accuracy 0.95
# Step 340 , training accuracy 0.93
# Step 350 , training accuracy 0.89
# Step 360 , training accuracy 0.91
# Step 370 , training accuracy 0.89
# Step 380 , training accuracy 0.94
# Step 390 , training accuracy 0.97
# Step 400 , training accuracy 0.88
# Step 410 , training accuracy 0.95
# Step 420 , training accuracy 0.97
# Step 430 , training accuracy 0.94
# Step 440 , training accuracy 0.97
# Step 450 , training accuracy 0.9
# Step 460 , training accuracy 0.93
# Step 470 , training accuracy 0.9
# Step 480 , training accuracy 0.92
# Step 490 , training accuracy 0.92
# Step 500 , training accuracy 0.93
# Step 510 , training accuracy 0.94
# Step 520 , training accuracy 0.93
# Step 530 , training accuracy 0.89
# Step 540 , training accuracy 0.91
# Step 550 , training accuracy 0.95
# Step 560 , training accuracy 0.88
# Step 570 , training accuracy 0.92
# Step 580 , training accuracy 0.98
# Step 590 , training accuracy 0.95
# Step 600 , training accuracy 0.92
# Step 610 , training accuracy 0.93
# Step 620 , training accuracy 0.94
# Step 630 , training accuracy 0.96
# Step 640 , training accuracy 0.92
# Step 650 , training accuracy 0.94
# Step 660 , training accuracy 0.92
# Step 670 , training accuracy 0.94
# Step 680 , training accuracy 0.99
# Step 690 , training accuracy 0.95
# Step 700 , training accuracy 0.97
# Step 710 , training accuracy 0.94
# Step 720 , training accuracy 0.98
# Step 730 , training accuracy 0.96
# Step 740 , training accuracy 0.91
# Step 750 , training accuracy 0.92
# Step 760 , training accuracy 0.98
# Step 770 , training accuracy 0.97
# Step 780 , training accuracy 0.96
# Step 790 , training accuracy 0.96
# Step 800 , training accuracy 0.96
# Step 810 , training accuracy 0.96
# Step 820 , training accuracy 0.95
# Step 830 , training accuracy 0.97
# Step 840 , training accuracy 0.95
# Step 850 , training accuracy 0.95
# Step 860 , training accuracy 0.96
# Step 870 , training accuracy 0.91
# Step 880 , training accuracy 0.98
# Step 890 , training accuracy 0.98
# Step 900 , training accuracy 0.95
# Step 910 , training accuracy 0.97
# Step 920 , training accuracy 0.97
# Step 930 , training accuracy 0.98
# Step 940 , training accuracy 0.98
# Step 950 , training accuracy 0.97
# Step 960 , training accuracy 0.94
# Step 970 , training accuracy 0.97
# Step 980 , training accuracy 0.94
# Step 990 , training accuracy 0.96
# Step 1000 , training accuracy 0.95
# Step 1010 , training accuracy 0.96
# Step 1020 , training accuracy 0.94
# Step 1030 , training accuracy 0.93
# Step 1040 , training accuracy 0.96
# Step 1050 , training accuracy 0.95
# Step 1060 , training accuracy 0.92
# Step 1070 , training accuracy 0.96
# Step 1080 , training accuracy 0.96
# Step 1090 , training accuracy 0.97
# Step 1100 , training accuracy 0.99
# Step 1110 , training accuracy 0.94
# Step 1120 , training accuracy 0.93
# Step 1130 , training accuracy 0.96
# Step 1140 , training accuracy 0.99
# Step 1150 , training accuracy 0.97
# Step 1160 , training accuracy 0.95
# Step 1170 , training accuracy 0.98
# Step 1180 , training accuracy 0.97
# Step 1190 , training accuracy 0.97
# Step 1200 , training accuracy 0.99
# Step 1210 , training accuracy 0.92
# Step 1220 , training accuracy 0.96
# Step 1230 , training accuracy 0.99
# Step 1240 , training accuracy 0.98
# Step 1250 , training accuracy 0.98
# Step 1260 , training accuracy 0.93
# Step 1270 , training accuracy 0.97
# Step 1280 , training accuracy 0.99
# Step 1290 , training accuracy 0.98
# Step 1300 , training accuracy 0.99
# Step 1310 , training accuracy 0.94
# Step 1320 , training accuracy 0.92
# Step 1330 , training accuracy 0.92
# Step 1340 , training accuracy 0.99
# Step 1350 , training accuracy 0.91
# Step 1360 , training accuracy 0.94
# Step 1370 , training accuracy 0.97
# Step 1380 , training accuracy 0.96
# Step 1390 , training accuracy 0.96
# Step 1400 , training accuracy 0.95
# Step 1410 , training accuracy 0.99
# Step 1420 , training accuracy 0.98
# Step 1430 , training accuracy 0.94
# Step 1440 , training accuracy 0.95
# Step 1450 , training accuracy 0.94
# Step 1460 , training accuracy 0.97
# Step 1470 , training accuracy 0.99
# Step 1480 , training accuracy 0.96
# Step 1490 , training accuracy 0.96
# Step 1500 , training accuracy 0.98
# Step 1510 , training accuracy 0.96
# Step 1520 , training accuracy 0.96
# Step 1530 , training accuracy 0.96
# Step 1540 , training accuracy 0.97
# Step 1550 , training accuracy 0.97
# Step 1560 , training accuracy 0.98
# Step 1570 , training accuracy 0.93
# Step 1580 , training accuracy 0.97
# Step 1590 , training accuracy 1
# Step 1600 , training accuracy 0.98
# Step 1610 , training accuracy 0.98
# Step 1620 , training accuracy 0.95
# Step 1630 , training accuracy 0.98
# Step 1640 , training accuracy 1
# Step 1650 , training accuracy 0.98
# Step 1660 , training accuracy 0.98
# Step 1670 , training accuracy 1
# Step 1680 , training accuracy 0.97
# Step 1690 , training accuracy 0.99
# Step 1700 , training accuracy 0.96
# Step 1710 , training accuracy 0.95
# Step 1720 , training accuracy 0.98
# Step 1730 , training accuracy 0.98
# Step 1740 , training accuracy 0.98
# Step 1750 , training accuracy 0.95
# Step 1760 , training accuracy 0.96
# Step 1770 , training accuracy 0.97
# Step 1780 , training accuracy 0.97
# Step 1790 , training accuracy 0.99
# Step 1800 , training accuracy 0.99
# Step 1810 , training accuracy 0.99
# Step 1820 , training accuracy 0.94
# Step 1830 , training accuracy 0.96
# Step 1840 , training accuracy 0.98
# Step 1850 , training accuracy 0.96
# Step 1860 , training accuracy 0.95
# Step 1870 , training accuracy 0.99
# Step 1880 , training accuracy 0.96
# Step 1890 , training accuracy 0.98
# Step 1900 , training accuracy 0.97
# Step 1910 , training accuracy 0.96
# Step 1920 , training accuracy 0.95
# Step 1930 , training accuracy 0.95
# Step 1940 , training accuracy 0.98
# Step 1950 , training accuracy 0.98
# Step 1960 , training accuracy 0.98
# Step 1970 , training accuracy 0.96
# Step 1980 , training accuracy 0.97
# Step 1990 , training accuracy 0.98
# Step 2000 , training accuracy 0.96
# Step 2010 , training accuracy 0.95
# Step 2020 , training accuracy 0.98
# Step 2030 , training accuracy 0.97
# Step 2040 , training accuracy 0.95
# Step 2050 , training accuracy 0.97
# Step 2060 , training accuracy 0.98
# Step 2070 , training accuracy 0.98
# Step 2080 , training accuracy 0.96
# Step 2090 , training accuracy 0.98
# Step 2100 , training accuracy 0.97
# Step 2110 , training accuracy 0.99
# Step 2120 , training accuracy 0.98
# Step 2130 , training accuracy 0.95
# Step 2140 , training accuracy 0.98
# Step 2150 , training accuracy 0.96
# Step 2160 , training accuracy 0.97
# Step 2170 , training accuracy 0.97
# Step 2180 , training accuracy 0.99
# Step 2190 , training accuracy 0.95
# Step 2200 , training accuracy 0.99
# Step 2210 , training accuracy 0.96
# Step 2220 , training accuracy 0.98
# Step 2230 , training accuracy 0.98
# Step 2240 , training accuracy 0.99
# Step 2250 , training accuracy 0.98
# Step 2260 , training accuracy 0.97
# Step 2270 , training accuracy 1
# Step 2280 , training accuracy 0.98
# Step 2290 , training accuracy 1
# Step 2300 , training accuracy 0.97
# Step 2310 , training accuracy 0.99
# Step 2320 , training accuracy 0.94
# Step 2330 , training accuracy 0.98
# Step 2340 , training accuracy 0.97
# Step 2350 , training accuracy 0.97
# Step 2360 , training accuracy 0.99
# Step 2370 , training accuracy 0.96
# Step 2380 , training accuracy 0.97
# Step 2390 , training accuracy 0.96
# Step 2400 , training accuracy 0.98
# Step 2410 , training accuracy 0.98
# Step 2420 , training accuracy 0.99
# Step 2430 , training accuracy 0.99
# Step 2440 , training accuracy 0.97
# Step 2450 , training accuracy 0.96
# Step 2460 , training accuracy 0.95
# Step 2470 , training accuracy 0.98
# Step 2480 , training accuracy 0.99
# Step 2490 , training accuracy 0.99
# Step 2500 , training accuracy 0.99
# Step 2510 , training accuracy 0.98
# Step 2520 , training accuracy 0.98
# Step 2530 , training accuracy 0.99
# Step 2540 , training accuracy 0.98
# Step 2550 , training accuracy 0.97
# Step 2560 , training accuracy 0.99
# Step 2570 , training accuracy 1
# Step 2580 , training accuracy 0.97
# Step 2590 , training accuracy 0.97
# Step 2600 , training accuracy 0.96
# Step 2610 , training accuracy 0.99
# Step 2620 , training accuracy 0.98
# Step 2630 , training accuracy 0.99
# Step 2640 , training accuracy 0.98
# Step 2650 , training accuracy 0.99
# Step 2660 , training accuracy 0.98
# Step 2670 , training accuracy 0.98
# Step 2680 , training accuracy 0.92
# Step 2690 , training accuracy 1
# Step 2700 , training accuracy 0.99
# Step 2710 , training accuracy 0.97
# Step 2720 , training accuracy 0.98
# Step 2730 , training accuracy 0.96
# Step 2740 , training accuracy 0.98
# Step 2750 , training accuracy 0.98
# Step 2760 , training accuracy 0.98
# Step 2770 , training accuracy 0.98
# Step 2780 , training accuracy 1
# Step 2790 , training accuracy 0.98
# Step 2800 , training accuracy 0.96
# Step 2810 , training accuracy 0.98
# Step 2820 , training accuracy 0.94
# Step 2830 , training accuracy 0.99
# Step 2840 , training accuracy 1
# Step 2850 , training accuracy 0.99
# Step 2860 , training accuracy 0.99
# Step 2870 , training accuracy 0.98
# Step 2880 , training accuracy 0.98
# Step 2890 , training accuracy 0.98
# Step 2900 , training accuracy 1
# Step 2910 , training accuracy 1
# Step 2920 , training accuracy 0.98
# Step 2930 , training accuracy 0.98
# Step 2940 , training accuracy 0.98
# Step 2950 , training accuracy 0.99
# Step 2960 , training accuracy 0.99
# Step 2970 , training accuracy 0.99
# Step 2980 , training accuracy 0.96
# Step 2990 , training accuracy 1
# Step 3000 , training accuracy 0.99
# Step 3010 , training accuracy 0.96
# Step 3020 , training accuracy 0.99
# Step 3030 , training accuracy 0.98
# Step 3040 , training accuracy 0.98
# Step 3050 , training accuracy 0.99
# Step 3060 , training accuracy 0.98
# Step 3070 , training accuracy 0.96
# Step 3080 , training accuracy 0.95
# Step 3090 , training accuracy 1
# Step 3100 , training accuracy 0.98
# Step 3110 , training accuracy 0.98
# Step 3120 , training accuracy 0.93
# Step 3130 , training accuracy 0.99
# Step 3140 , training accuracy 1
# Step 3150 , training accuracy 1
# Step 3160 , training accuracy 0.96
# Step 3170 , training accuracy 1
# Step 3180 , training accuracy 0.98
# Step 3190 , training accuracy 0.99
# Step 3200 , training accuracy 0.98
# Step 3210 , training accuracy 0.98
# Step 3220 , training accuracy 0.99
# Step 3230 , training accuracy 1
# Step 3240 , training accuracy 0.99
# Step 3250 , training accuracy 1
# Step 3260 , training accuracy 0.94
# Step 3270 , training accuracy 0.99
# Step 3280 , training accuracy 0.97
# Step 3290 , training accuracy 1
# Step 3300 , training accuracy 1
# Step 3310 , training accuracy 0.98
# Step 3320 , training accuracy 0.98
# Step 3330 , training accuracy 0.97
# Step 3340 , training accuracy 1
# Step 3350 , training accuracy 1
# Step 3360 , training accuracy 1
# Step 3370 , training accuracy 0.99
# Step 3380 , training accuracy 1
# Step 3390 , training accuracy 1
# Step 3400 , training accuracy 1
# Step 3410 , training accuracy 0.97
# Step 3420 , training accuracy 0.97
# Step 3430 , training accuracy 0.96
# Step 3440 , training accuracy 0.97
# Step 3450 , training accuracy 0.99
# Step 3460 , training accuracy 0.99
# Step 3470 , training accuracy 0.97
# Step 3480 , training accuracy 0.98
# Step 3490 , training accuracy 0.99
# Step 3500 , training accuracy 0.98
# Step 3510 , training accuracy 1
# Step 3520 , training accuracy 1
# Step 3530 , training accuracy 0.99
# Step 3540 , training accuracy 0.97
# Step 3550 , training accuracy 0.99
# Step 3560 , training accuracy 0.99
# Step 3570 , training accuracy 1
# Step 3580 , training accuracy 0.98
# Step 3590 , training accuracy 1
# Step 3600 , training accuracy 0.97
# Step 3610 , training accuracy 0.99
# Step 3620 , training accuracy 0.99
# Step 3630 , training accuracy 0.96
# Step 3640 , training accuracy 0.98
# Step 3650 , training accuracy 0.97
# Step 3660 , training accuracy 1
# Step 3670 , training accuracy 1
# Step 3680 , training accuracy 1
# Step 3690 , training accuracy 0.98
# Step 3700 , training accuracy 0.99
# Step 3710 , training accuracy 0.99
# Step 3720 , training accuracy 0.97
# Step 3730 , training accuracy 0.98
# Step 3740 , training accuracy 0.98
# Step 3750 , training accuracy 0.97
# Step 3760 , training accuracy 0.99
# Step 3770 , training accuracy 1
# Step 3780 , training accuracy 0.99
# Step 3790 , training accuracy 0.98
# Step 3800 , training accuracy 1
# Step 3810 , training accuracy 0.99
# Step 3820 , training accuracy 0.98
# Step 3830 , training accuracy 0.99
# Step 3840 , training accuracy 0.99
# Step 3850 , training accuracy 0.97
# Step 3860 , training accuracy 1
# Step 3870 , training accuracy 0.95
# Step 3880 , training accuracy 1
# Step 3890 , training accuracy 0.98
# Step 3900 , training accuracy 0.99
# Step 3910 , training accuracy 0.99
# Step 3920 , training accuracy 0.98
# Step 3930 , training accuracy 0.99
# Step 3940 , training accuracy 0.99
# Step 3950 , training accuracy 1
# Step 3960 , training accuracy 0.96
# Step 3970 , training accuracy 0.99
# Step 3980 , training accuracy 0.98
# Step 3990 , training accuracy 0.98
# Step 4000 , training accuracy 1
# Step 4010 , training accuracy 1
# Step 4020 , training accuracy 0.99
# Step 4030 , training accuracy 0.99
# Step 4040 , training accuracy 0.99
# Step 4050 , training accuracy 1
# Step 4060 , training accuracy 0.98
# Step 4070 , training accuracy 0.98
# Step 4080 , training accuracy 0.99
# Step 4090 , training accuracy 0.98
# Step 4100 , training accuracy 0.99
# Step 4110 , training accuracy 0.97
# Step 4120 , training accuracy 1
# Step 4130 , training accuracy 1
# Step 4140 , training accuracy 0.99
# Step 4150 , training accuracy 0.98
# Step 4160 , training accuracy 0.99
# Step 4170 , training accuracy 1
# Step 4180 , training accuracy 0.98
# Step 4190 , training accuracy 0.98
# Step 4200 , training accuracy 0.98
# Step 4210 , training accuracy 0.98
# Step 4220 , training accuracy 0.97
# Step 4230 , training accuracy 0.99
# Step 4240 , training accuracy 0.97
# Step 4250 , training accuracy 1
# Step 4260 , training accuracy 0.99
# Step 4270 , training accuracy 0.97
# Step 4280 , training accuracy 0.98
# Step 4290 , training accuracy 1
# Step 4300 , training accuracy 0.99
# Step 4310 , training accuracy 0.98
# Step 4320 , training accuracy 1
# Step 4330 , training accuracy 1
# Step 4340 , training accuracy 1
# Step 4350 , training accuracy 1
# Step 4360 , training accuracy 0.99
# Step 4370 , training accuracy 1
# Step 4380 , training accuracy 0.99
# Step 4390 , training accuracy 1
# Step 4400 , training accuracy 0.99
# Step 4410 , training accuracy 0.99
# Step 4420 , training accuracy 0.97
# Step 4430 , training accuracy 1
# Step 4440 , training accuracy 0.99
# Step 4450 , training accuracy 1
# Step 4460 , training accuracy 1
# Step 4470 , training accuracy 0.99
# Step 4480 , training accuracy 0.99
# Step 4490 , training accuracy 0.98
# Step 4500 , training accuracy 1
# Step 4510 , training accuracy 1
# Step 4520 , training accuracy 0.99
# Step 4530 , training accuracy 0.98
# Step 4540 , training accuracy 0.98
# Step 4550 , training accuracy 1
# Step 4560 , training accuracy 0.99
# Step 4570 , training accuracy 1
# Step 4580 , training accuracy 0.98
# Step 4590 , training accuracy 1
# Step 4600 , training accuracy 1
# Step 4610 , training accuracy 1
# Step 4620 , training accuracy 1
# Step 4630 , training accuracy 0.99
# Step 4640 , training accuracy 0.99
# Step 4650 , training accuracy 1
# Step 4660 , training accuracy 0.98
# Step 4670 , training accuracy 1
# Step 4680 , training accuracy 0.99
# Step 4690 , training accuracy 1
# Step 4700 , training accuracy 0.99
# Step 4710 , training accuracy 1
# Step 4720 , training accuracy 1
# Step 4730 , training accuracy 0.99
# Step 4740 , training accuracy 1
# Step 4750 , training accuracy 1
# Step 4760 , training accuracy 0.98
# Step 4770 , training accuracy 1
# Step 4780 , training accuracy 0.99
# Step 4790 , training accuracy 0.99
# Step 4800 , training accuracy 0.99
# Step 4810 , training accuracy 0.98
# Step 4820 , training accuracy 0.98
# Step 4830 , training accuracy 0.99
# Step 4840 , training accuracy 0.99
# Step 4850 , training accuracy 0.99
# Step 4860 , training accuracy 1
# Step 4870 , training accuracy 0.99
# Step 4880 , training accuracy 1
# Step 4890 , training accuracy 0.99
# Step 4900 , training accuracy 0.99
# Step 4910 , training accuracy 1
# Step 4920 , training accuracy 1
# Step 4930 , training accuracy 1
# Step 4940 , training accuracy 0.99
# Step 4950 , training accuracy 0.99
# Step 4960 , training accuracy 1
# Step 4970 , training accuracy 0.99
# Step 4980 , training accuracy 0.99
# Step 4990 , training accuracy 0.98
# Step 5000 , training accuracy 0.99
# Step 5010 , training accuracy 0.99
# Step 5020 , training accuracy 1
# Step 5030 , training accuracy 0.97
# Step 5040 , training accuracy 0.99
# Step 5050 , training accuracy 0.98
# Step 5060 , training accuracy 0.99
# Step 5070 , training accuracy 1
# Step 5080 , training accuracy 0.99
# Step 5090 , training accuracy 1
# Step 5100 , training accuracy 0.98
# Step 5110 , training accuracy 1
# Step 5120 , training accuracy 0.98
# Step 5130 , training accuracy 1
# Step 5140 , training accuracy 0.99
# Step 5150 , training accuracy 1
# Step 5160 , training accuracy 1
# Step 5170 , training accuracy 0.95
# Step 5180 , training accuracy 1
# Step 5190 , training accuracy 0.99
# Step 5200 , training accuracy 1
# Step 5210 , training accuracy 1
# Step 5220 , training accuracy 1
# Step 5230 , training accuracy 0.99
# Step 5240 , training accuracy 0.99
# Step 5250 , training accuracy 1
# Step 5260 , training accuracy 0.99
# Step 5270 , training accuracy 0.99
# Step 5280 , training accuracy 0.98
# Step 5290 , training accuracy 0.99
# Step 5300 , training accuracy 0.98
# Step 5310 , training accuracy 1
# Step 5320 , training accuracy 0.99
# Step 5330 , training accuracy 0.97
# Step 5340 , training accuracy 0.99
# Step 5350 , training accuracy 0.99
# Step 5360 , training accuracy 1
# Step 5370 , training accuracy 0.99
# Step 5380 , training accuracy 1
# Step 5390 , training accuracy 0.98
# Step 5400 , training accuracy 1
# Step 5410 , training accuracy 1
# Step 5420 , training accuracy 0.99
# Step 5430 , training accuracy 0.99
# Step 5440 , training accuracy 0.96
# Step 5450 , training accuracy 0.99
# Step 5460 , training accuracy 1
# Step 5470 , training accuracy 0.99
# Step 5480 , training accuracy 0.99
# Step 5490 , training accuracy 0.98
# Step 5500 , training accuracy 0.96
# Step 5510 , training accuracy 0.97
# Step 5520 , training accuracy 1
# Step 5530 , training accuracy 0.99
# Step 5540 , training accuracy 0.98
# Step 5550 , training accuracy 1
# Step 5560 , training accuracy 1
# Step 5570 , training accuracy 0.96
# Step 5580 , training accuracy 0.99
# Step 5590 , training accuracy 1
# Step 5600 , training accuracy 0.99
# Step 5610 , training accuracy 1
# Step 5620 , training accuracy 1
# Step 5630 , training accuracy 0.99
# Step 5640 , training accuracy 1
# Step 5650 , training accuracy 0.99
# Step 5660 , training accuracy 1
# Step 5670 , training accuracy 1
# Step 5680 , training accuracy 1
# Step 5690 , training accuracy 1
# Step 5700 , training accuracy 0.99
# Step 5710 , training accuracy 0.99
# Step 5720 , training accuracy 1
# Step 5730 , training accuracy 1
# Step 5740 , training accuracy 1
# Step 5750 , training accuracy 1
# Step 5760 , training accuracy 1
# Step 5770 , training accuracy 1
# Step 5780 , training accuracy 1
# Step 5790 , training accuracy 0.99
# Step 5800 , training accuracy 1
# Step 5810 , training accuracy 1
# Step 5820 , training accuracy 0.99
# Step 5830 , training accuracy 1
# Step 5840 , training accuracy 0.98
# Step 5850 , training accuracy 0.97
# Step 5860 , training accuracy 1
# Step 5870 , training accuracy 0.99
# Step 5880 , training accuracy 0.99
# Step 5890 , training accuracy 1
# Step 5900 , training accuracy 1
# Step 5910 , training accuracy 0.99
# Step 5920 , training accuracy 0.98
# Step 5930 , training accuracy 0.99
# Step 5940 , training accuracy 1
# Step 5950 , training accuracy 0.99
# Step 5960 , training accuracy 0.99
# Step 5970 , training accuracy 1
# Step 5980 , training accuracy 1
# Step 5990 , training accuracy 0.99
# Step 6000 , training accuracy 1
# Step 6010 , training accuracy 0.99
# Step 6020 , training accuracy 1
# Step 6030 , training accuracy 0.99
# Step 6040 , training accuracy 1
# Step 6050 , training accuracy 1
# Step 6060 , training accuracy 0.99
# Step 6070 , training accuracy 1
# Step 6080 , training accuracy 0.99
# Step 6090 , training accuracy 1
# Step 6100 , training accuracy 0.99
# Step 6110 , training accuracy 0.99
# Step 6120 , training accuracy 1
# Step 6130 , training accuracy 1
# Step 6140 , training accuracy 1
# Step 6150 , training accuracy 0.99
# Step 6160 , training accuracy 1
# Step 6170 , training accuracy 1
# Step 6180 , training accuracy 1
# Step 6190 , training accuracy 0.99
# Step 6200 , training accuracy 0.99
# Step 6210 , training accuracy 0.98
# Step 6220 , training accuracy 0.99
# Step 6230 , training accuracy 1
# Step 6240 , training accuracy 0.98
# Step 6250 , training accuracy 1
# Step 6260 , training accuracy 1
# Step 6270 , training accuracy 1
# Step 6280 , training accuracy 1
# Step 6290 , training accuracy 1
# Step 6300 , training accuracy 0.99
# Step 6310 , training accuracy 1
# Step 6320 , training accuracy 1
# Step 6330 , training accuracy 0.99
# Step 6340 , training accuracy 1
# Step 6350 , training accuracy 0.99
# Step 6360 , training accuracy 1
# Step 6370 , training accuracy 1
# Step 6380 , training accuracy 0.99
# Step 6390 , training accuracy 0.99
# Step 6400 , training accuracy 0.99
# Step 6410 , training accuracy 1
# Step 6420 , training accuracy 1
# Step 6430 , training accuracy 1
# Step 6440 , training accuracy 0.99
# Step 6450 , training accuracy 1
# Step 6460 , training accuracy 1
# Step 6470 , training accuracy 1
# Step 6480 , training accuracy 1
# Step 6490 , training accuracy 1
# Step 6500 , training accuracy 1
# Step 6510 , training accuracy 0.98
# Step 6520 , training accuracy 1
# Step 6530 , training accuracy 0.98
# Step 6540 , training accuracy 0.99
# Step 6550 , training accuracy 1
# Step 6560 , training accuracy 0.99
# Step 6570 , training accuracy 1
# Step 6580 , training accuracy 1
# Step 6590 , training accuracy 1
# Step 6600 , training accuracy 0.99
# Step 6610 , training accuracy 1
# Step 6620 , training accuracy 1
# Step 6630 , training accuracy 1
# Step 6640 , training accuracy 1
# Step 6650 , training accuracy 1
# Step 6660 , training accuracy 0.99
# Step 6670 , training accuracy 1
# Step 6680 , training accuracy 1
# Step 6690 , training accuracy 0.99
# Step 6700 , training accuracy 1
# Step 6710 , training accuracy 0.99
# Step 6720 , training accuracy 1
# Step 6730 , training accuracy 0.98
# Step 6740 , training accuracy 1
# Step 6750 , training accuracy 1
# Step 6760 , training accuracy 1
# Step 6770 , training accuracy 0.99
# Step 6780 , training accuracy 0.99
# Step 6790 , training accuracy 1
# Step 6800 , training accuracy 1
# Step 6810 , training accuracy 0.99
# Step 6820 , training accuracy 1
# Step 6830 , training accuracy 1
# Step 6840 , training accuracy 1
# Step 6850 , training accuracy 0.99
# Step 6860 , training accuracy 1
# Step 6870 , training accuracy 1
# Step 6880 , training accuracy 0.99
# Step 6890 , training accuracy 1
# Step 6900 , training accuracy 0.99
# Step 6910 , training accuracy 0.99
# Step 6920 , training accuracy 1
# Step 6930 , training accuracy 1
# Step 6940 , training accuracy 1
# Step 6950 , training accuracy 1
# Step 6960 , training accuracy 0.99
# Step 6970 , training accuracy 1
# Step 6980 , training accuracy 1
# Step 6990 , training accuracy 1
# Step 7000 , training accuracy 1
# Step 7010 , training accuracy 1
# Step 7020 , training accuracy 1
# Step 7030 , training accuracy 0.99
# Step 7040 , training accuracy 1
# Step 7050 , training accuracy 1
# Step 7060 , training accuracy 0.99
# Step 7070 , training accuracy 1
# Step 7080 , training accuracy 1
# Step 7090 , training accuracy 0.98
# Step 7100 , training accuracy 1
# Step 7110 , training accuracy 1
# Step 7120 , training accuracy 0.99
# Step 7130 , training accuracy 1
# Step 7140 , training accuracy 1
# Step 7150 , training accuracy 1
# Step 7160 , training accuracy 1
# Step 7170 , training accuracy 0.99
# Step 7180 , training accuracy 1
# Step 7190 , training accuracy 1
# Step 7200 , training accuracy 1
# Step 7210 , training accuracy 1
# Step 7220 , training accuracy 0.99
# Step 7230 , training accuracy 1
# Step 7240 , training accuracy 1
# Step 7250 , training accuracy 0.99
# Step 7260 , training accuracy 1
# Step 7270 , training accuracy 0.99
# Step 7280 , training accuracy 0.99
# Step 7290 , training accuracy 0.99
# Step 7300 , training accuracy 1
# Step 7310 , training accuracy 1
# Step 7320 , training accuracy 1
# Step 7330 , training accuracy 1
# Step 7340 , training accuracy 1
# Step 7350 , training accuracy 1
# Step 7360 , training accuracy 0.98
# Step 7370 , training accuracy 1
# Step 7380 , training accuracy 1
# Step 7390 , training accuracy 1
# Step 7400 , training accuracy 1
# Step 7410 , training accuracy 1
# Step 7420 , training accuracy 1
# Step 7430 , training accuracy 1
# Step 7440 , training accuracy 1
# Step 7450 , training accuracy 0.99
# Step 7460 , training accuracy 1
# Step 7470 , training accuracy 1
# Step 7480 , training accuracy 0.99
# Step 7490 , training accuracy 1
# Step 7500 , training accuracy 0.99
# Step 7510 , training accuracy 0.99
# Step 7520 , training accuracy 0.99
# Step 7530 , training accuracy 1
# Step 7540 , training accuracy 1
# Step 7550 , training accuracy 1
# Step 7560 , training accuracy 1
# Step 7570 , training accuracy 0.99
# Step 7580 , training accuracy 1
# Step 7590 , training accuracy 0.98
# Step 7600 , training accuracy 1
# Step 7610 , training accuracy 1
# Step 7620 , training accuracy 1
# Step 7630 , training accuracy 1
# Step 7640 , training accuracy 0.99
# Step 7650 , training accuracy 0.99
# Step 7660 , training accuracy 1
# Step 7670 , training accuracy 0.98
# Step 7680 , training accuracy 0.99
# Step 7690 , training accuracy 0.99
# Step 7700 , training accuracy 1
# Step 7710 , training accuracy 1
# Step 7720 , training accuracy 0.99
# Step 7730 , training accuracy 1
# Step 7740 , training accuracy 1
# Step 7750 , training accuracy 1
# Step 7760 , training accuracy 0.99
# Step 7770 , training accuracy 1
# Step 7780 , training accuracy 1
# Step 7790 , training accuracy 1
# Step 7800 , training accuracy 1
# Step 7810 , training accuracy 1
# Step 7820 , training accuracy 1
# Step 7830 , training accuracy 1
# Step 7840 , training accuracy 1
# Step 7850 , training accuracy 1
# Step 7860 , training accuracy 0.99
# Step 7870 , training accuracy 0.99
# Step 7880 , training accuracy 1
# Step 7890 , training accuracy 1
# Step 7900 , training accuracy 1
# Step 7910 , training accuracy 1
# Step 7920 , training accuracy 0.99
# Step 7930 , training accuracy 0.98
# Step 7940 , training accuracy 1
# Step 7950 , training accuracy 0.99
# Step 7960 , training accuracy 1
# Step 7970 , training accuracy 1
# Step 7980 , training accuracy 0.99
# Step 7990 , training accuracy 1
# Step 8000 , training accuracy 1
# Step 8010 , training accuracy 1
# Step 8020 , training accuracy 1
# Step 8030 , training accuracy 0.99
# Step 8040 , training accuracy 1
# Step 8050 , training accuracy 1
# Step 8060 , training accuracy 0.99
# Step 8070 , training accuracy 1
# Step 8080 , training accuracy 1
# Step 8090 , training accuracy 0.99
# Step 8100 , training accuracy 1
# Step 8110 , training accuracy 1
# Step 8120 , training accuracy 0.99
# Step 8130 , training accuracy 0.99
# Step 8140 , training accuracy 1
# Step 8150 , training accuracy 1
# Step 8160 , training accuracy 1
# Step 8170 , training accuracy 1
# Step 8180 , training accuracy 1
# Step 8190 , training accuracy 1
# Step 8200 , training accuracy 0.99
# Step 8210 , training accuracy 1
# Step 8220 , training accuracy 1
# Step 8230 , training accuracy 0.99
# Step 8240 , training accuracy 1
# Step 8250 , training accuracy 0.99
# Step 8260 , training accuracy 1
# Step 8270 , training accuracy 1
# Step 8280 , training accuracy 1
# Step 8290 , training accuracy 1
# Step 8300 , training accuracy 1
# Step 8310 , training accuracy 1
# Step 8320 , training accuracy 1
# Step 8330 , training accuracy 1
# Step 8340 , training accuracy 0.98
# Step 8350 , training accuracy 0.99
# Step 8360 , training accuracy 0.99
# Step 8370 , training accuracy 1
# Step 8380 , training accuracy 1
# Step 8390 , training accuracy 0.99
# Step 8400 , training accuracy 1
# Step 8410 , training accuracy 1
# Step 8420 , training accuracy 1
# Step 8430 , training accuracy 1
# Step 8440 , training accuracy 0.99
# Step 8450 , training accuracy 1
# Step 8460 , training accuracy 1
# Step 8470 , training accuracy 1
# Step 8480 , training accuracy 1
# Step 8490 , training accuracy 1
# Step 8500 , training accuracy 1
# Step 8510 , training accuracy 1
# Step 8520 , training accuracy 1
# Step 8530 , training accuracy 1
# Step 8540 , training accuracy 1
# Step 8550 , training accuracy 1
# Step 8560 , training accuracy 0.98
# Step 8570 , training accuracy 1
# Step 8580 , training accuracy 1
# Step 8590 , training accuracy 0.99
# Step 8600 , training accuracy 1
# Step 8610 , training accuracy 1
# Step 8620 , training accuracy 1
# Step 8630 , training accuracy 0.99
# Step 8640 , training accuracy 1
# Step 8650 , training accuracy 1
# Step 8660 , training accuracy 0.98
# Step 8670 , training accuracy 1
# Step 8680 , training accuracy 0.98
# Step 8690 , training accuracy 1
# Step 8700 , training accuracy 0.99
# Step 8710 , training accuracy 1
# Step 8720 , training accuracy 1
# Step 8730 , training accuracy 0.98
# Step 8740 , training accuracy 0.99
# Step 8750 , training accuracy 1
# Step 8760 , training accuracy 1
# Step 8770 , training accuracy 1
# Step 8780 , training accuracy 0.99
# Step 8790 , training accuracy 1
# Step 8800 , training accuracy 1
# Step 8810 , training accuracy 0.99
# Step 8820 , training accuracy 1
# Step 8830 , training accuracy 0.99
# Step 8840 , training accuracy 1
# Step 8850 , training accuracy 1
# Step 8860 , training accuracy 1
# Step 8870 , training accuracy 1
# Step 8880 , training accuracy 1
# Step 8890 , training accuracy 1
# Step 8900 , training accuracy 0.99
# Step 8910 , training accuracy 1
# Step 8920 , training accuracy 0.99
# Step 8930 , training accuracy 1
# Step 8940 , training accuracy 1
# Step 8950 , training accuracy 1
# Step 8960 , training accuracy 0.99
# Step 8970 , training accuracy 0.99
# Step 8980 , training accuracy 1
# Step 8990 , training accuracy 1
# Step 9000 , training accuracy 1
# Step 9010 , training accuracy 1
# Step 9020 , training accuracy 1
# Step 9030 , training accuracy 1
# Step 9040 , training accuracy 1
# Step 9050 , training accuracy 1
# Step 9060 , training accuracy 0.99
# Step 9070 , training accuracy 1
# Step 9080 , training accuracy 1
# Step 9090 , training accuracy 1
# Step 9100 , training accuracy 1
# Step 9110 , training accuracy 1
# Step 9120 , training accuracy 1
# Step 9130 , training accuracy 1
# Step 9140 , training accuracy 0.99
# Step 9150 , training accuracy 0.99
# Step 9160 , training accuracy 1
# Step 9170 , training accuracy 1
# Step 9180 , training accuracy 1
# Step 9190 , training accuracy 1
# Step 9200 , training accuracy 1
# Step 9210 , training accuracy 1
# Step 9220 , training accuracy 1
# Step 9230 , training accuracy 1
# Step 9240 , training accuracy 1
# Step 9250 , training accuracy 1
# Step 9260 , training accuracy 1
# Step 9270 , training accuracy 1
# Step 9280 , training accuracy 1
# Step 9290 , training accuracy 0.99
# Step 9300 , training accuracy 1
# Step 9310 , training accuracy 0.99
# Step 9320 , training accuracy 0.99
# Step 9330 , training accuracy 1
# Step 9340 , training accuracy 1
# Step 9350 , training accuracy 1
# Step 9360 , training accuracy 0.99
# Step 9370 , training accuracy 1
# Step 9380 , training accuracy 0.99
# Step 9390 , training accuracy 1
# Step 9400 , training accuracy 1
# Step 9410 , training accuracy 0.99
# Step 9420 , training accuracy 1
# Step 9430 , training accuracy 1
# Step 9440 , training accuracy 1
# Step 9450 , training accuracy 1
# Step 9460 , training accuracy 1
# Step 9470 , training accuracy 1
# Step 9480 , training accuracy 0.98
# Step 9490 , training accuracy 1
# Step 9500 , training accuracy 1
# Step 9510 , training accuracy 1
# Step 9520 , training accuracy 0.99
# Step 9530 , training accuracy 1
# Step 9540 , training accuracy 1
# Step 9550 , training accuracy 1
# Step 9560 , training accuracy 1
# Step 9570 , training accuracy 1
# Step 9580 , training accuracy 1
# Step 9590 , training accuracy 0.99
# Step 9600 , training accuracy 1
# Step 9610 , training accuracy 1
# Step 9620 , training accuracy 0.98
# Step 9630 , training accuracy 1
# Step 9640 , training accuracy 0.99
# Step 9650 , training accuracy 1
# Step 9660 , training accuracy 1
# Step 9670 , training accuracy 1
# Step 9680 , training accuracy 1
# Step 9690 , training accuracy 1
# Step 9700 , training accuracy 1
# Step 9710 , training accuracy 1
# Step 9720 , training accuracy 1
# Step 9730 , training accuracy 1
# Step 9740 , training accuracy 0.99
# Step 9750 , training accuracy 1
# Step 9760 , training accuracy 1
# Step 9770 , training accuracy 1
# Step 9780 , training accuracy 1
# Step 9790 , training accuracy 1
# Step 9800 , training accuracy 1
# Step 9810 , training accuracy 1
# Step 9820 , training accuracy 1
# Step 9830 , training accuracy 1
# Step 9840 , training accuracy 1
# Step 9850 , training accuracy 1
# Step 9860 , training accuracy 1
# Step 9870 , training accuracy 0.99
# Step 9880 , training accuracy 1
# Step 9890 , training accuracy 1
# Step 9900 , training accuracy 1
# Step 9910 , training accuracy 1
# Step 9920 , training accuracy 0.99
# Step 9930 , training accuracy 1
# Step 9940 , training accuracy 1
# Step 9950 , training accuracy 1
# Step 9960 , training accuracy 1
# Step 9970 , training accuracy 1
# Step 9980 , training accuracy 1
# Step 9990 , training accuracy 1
# testing accuracy: 0.9757999777793884
